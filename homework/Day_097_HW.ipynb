# %%
import keras
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.optimizers import RMSprop, Adam
import os
# Out:
# Using TensorFlow backend.
# C:\Users\admin\Anaconda3\envs\tf\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\admin\Anaconda3\envs\tf\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\admin\Anaconda3\envs\tf\lib\site-packages\tensorflow\python\framework\dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\admin\Anaconda3\envs\tf\lib\site-packages\tensorflow\python\framework\dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\admin\Anaconda3\envs\tf\lib\site-packages\tensorflow\python\framework\dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\admin\Anaconda3\envs\tf\lib\site-packages\tensorflow\python\framework\dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
batch_size = 128 # batch 的大小，如果出現 OOM error，請降低這個值
num_classes = 10 # 類別的數量，Cifar 10 共有 10 個類別
epochs = 10 # 訓練的 epochs 數量

# 讀取資料並檢視
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# 對 label 進行 one-hot encoding (y_trian 原本是純數字)
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %% [markdown]
# ## 首先我們使用一般的 DNN (MLP) 來訓練
# 由於 DNN 只能輸入一維的資料，我們要先將影像進行攤平，若 (50000, 32, 32, 3) 的影像，攤平後會變成 (50000, 32*32*3) = (50000, 3072)

# %%
# 將資料攤平成一維資料
x_train = x_train.reshape(50000, 3072) 
x_test = x_test.reshape(10000, 3072)

# 將資料變為 float32 並標準化
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# 50000 train samples
# 10000 test samples

# %%
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(3072,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))

model.summary()

model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# WARNING:tensorflow:From C:\Users\admin\Anaconda3\envs\tf\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 512)               1573376
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 1,841,162
# Trainable params: 1,841,162
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:From C:\Users\admin\Anaconda3\envs\tf\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 21s 414us/step - loss: 2.2039 - accuracy: 0.2529 - val_loss: 1.9319 - val_accuracy: 0.3035
# Epoch 2/10
# 50000/50000 [==============================] - 21s 413us/step - loss: 1.8523 - accuracy: 0.3317 - val_loss: 1.7651 - val_accuracy: 0.3687
# Epoch 3/10
# 50000/50000 [==============================] - 21s 417us/step - loss: 1.7813 - accuracy: 0.3607 - val_loss: 1.7530 - val_accuracy: 0.3548
# Epoch 4/10
# 50000/50000 [==============================] - 21s 425us/step - loss: 1.7323 - accuracy: 0.3770 - val_loss: 1.7274 - val_accuracy: 0.3631
# Epoch 5/10
# 50000/50000 [==============================] - 20s 392us/step - loss: 1.6966 - accuracy: 0.3914 - val_loss: 1.6808 - val_accuracy: 0.3866
# Epoch 6/10
# 50000/50000 [==============================] - 20s 404us/step - loss: 1.6728 - accuracy: 0.4016 - val_loss: 1.6317 - val_accuracy: 0.4200
# Epoch 7/10
# 50000/50000 [==============================] - 20s 392us/step - loss: 1.6452 - accuracy: 0.4106 - val_loss: 1.6111 - val_accuracy: 0.4206
# Epoch 8/10
# 50000/50000 [==============================] - 18s 356us/step - loss: 1.6330 - accuracy: 0.4169 - val_loss: 1.5858 - val_accuracy: 0.4336
# Epoch 9/10
# 50000/50000 [==============================] - 17s 339us/step - loss: 1.6147 - accuracy: 0.4223 - val_loss: 1.6052 - val_accuracy: 0.4317
# Epoch 10/10
# 50000/50000 [==============================] - 18s 362us/step - loss: 1.6017 - accuracy: 0.4258 - val_loss: 1.5422 - val_accuracy: 0.4545
# Test loss: 1.5421837936401368
# Test accuracy: 0.4544999897480011

# %% [markdown]
# ## 接下來我們使用 CNN 來訓練神經網路
# CNN 的原理非常適合處理影像類的資料，就讓我們來看看，同樣的訓練條件，CNN 是否顯著優於 DNN 呢?

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), padding='same',
                 input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))
model.summary()

model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_5 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# activation_7 (Activation)    (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 30, 30, 32)        9248
# _________________________________________________________________
# activation_8 (Activation)    (None, 30, 30, 32)        0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 15, 15, 64)        18496
# _________________________________________________________________
# activation_9 (Activation)    (None, 15, 15, 64)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 13, 13, 64)        36928
# _________________________________________________________________
# activation_10 (Activation)   (None, 13, 13, 64)        0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               1180160
# _________________________________________________________________
# activation_11 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                5130
# _________________________________________________________________
# activation_12 (Activation)   (None, 10)                0
# =================================================================
# Total params: 1,250,858
# Trainable params: 1,250,858
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 236s 5ms/step - loss: 1.7413 - accuracy: 0.3665 - val_loss: 1.3078 - val_accuracy: 0.5216
# Epoch 2/10
# 50000/50000 [==============================] - 228s 5ms/step - loss: 1.3242 - accuracy: 0.5275 - val_loss: 1.1504 - val_accuracy: 0.5915
# Epoch 3/10
# 50000/50000 [==============================] - 227s 5ms/step - loss: 1.1223 - accuracy: 0.6034 - val_loss: 1.0660 - val_accuracy: 0.6348
# Epoch 4/10
# 50000/50000 [==============================] - 226s 5ms/step - loss: 0.9932 - accuracy: 0.6513 - val_loss: 0.8503 - val_accuracy: 0.7063
# Epoch 5/10
# 50000/50000 [==============================] - 232s 5ms/step - loss: 0.8986 - accuracy: 0.6863 - val_loss: 0.8575 - val_accuracy: 0.7052
# Epoch 6/10
# 50000/50000 [==============================] - 227s 5ms/step - loss: 0.8264 - accuracy: 0.7140 - val_loss: 0.8219 - val_accuracy: 0.7161
# Epoch 7/10
# 50000/50000 [==============================] - 225s 5ms/step - loss: 0.7768 - accuracy: 0.7311 - val_loss: 0.7343 - val_accuracy: 0.7457
# Epoch 8/10
# 50000/50000 [==============================] - 225s 4ms/step - loss: 0.7389 - accuracy: 0.7420 - val_loss: 0.7471 - val_accuracy: 0.7428
# Epoch 9/10
# 50000/50000 [==============================] - 225s 4ms/step - loss: 0.7026 - accuracy: 0.7570 - val_loss: 0.7527 - val_accuracy: 0.7406
# Epoch 10/10
# 50000/50000 [==============================] - 229s 5ms/step - loss: 0.6749 - accuracy: 0.7660 - val_loss: 0.6856 - val_accuracy: 0.7644
# Test loss: 0.6856017858505249
# Test accuracy: 0.7644000053405762

# %% [markdown]
# ## 同樣運算 10 個 epochs，但 CNN 在 test data 的準確率顯著優於 DNN!

# %% [markdown]
# ## 作業
#     1.請試著調整各個超參數，並說明那些超參數對於結果有明顯的影響?

# %% [markdown]
# ## 將DNN的RMSprop optimizer learning default是0.001，改成0.002，發現準確度下降，接著將epoch從10改成50，準確度還是較低

# %%
epochs=50

model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(3072,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))

model.summary()

model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(lr=0.02),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_20 (Dense)             (None, 512)               1573376
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_21 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_22 (Dense)             (None, 10)                5130
# =================================================================
# Total params: 1,841,162
# Trainable params: 1,841,162
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 19s 377us/step - loss: 2.4786 - accuracy: 0.2079 - val_loss: 1.9281 - val_accuracy: 0.2767
# Epoch 2/50
# 50000/50000 [==============================] - 18s 369us/step - loss: 1.9686 - accuracy: 0.2718 - val_loss: 1.9983 - val_accuracy: 0.2581
# Epoch 3/50
# 50000/50000 [==============================] - 18s 369us/step - loss: 1.9322 - accuracy: 0.2871 - val_loss: 1.9436 - val_accuracy: 0.2762
# Epoch 4/50
# 50000/50000 [==============================] - 17s 347us/step - loss: 1.9146 - accuracy: 0.2974 - val_loss: 1.8168 - val_accuracy: 0.3541
# Epoch 5/50
# 50000/50000 [==============================] - 17s 346us/step - loss: 1.9016 - accuracy: 0.2995 - val_loss: 1.8625 - val_accuracy: 0.2982
# Epoch 6/50
# 50000/50000 [==============================] - 17s 347us/step - loss: 1.8898 - accuracy: 0.3090 - val_loss: 1.8031 - val_accuracy: 0.3366
# Epoch 7/50
# 50000/50000 [==============================] - 17s 347us/step - loss: 1.8801 - accuracy: 0.3141 - val_loss: 1.7994 - val_accuracy: 0.3497
# Epoch 8/50
# 50000/50000 [==============================] - 18s 353us/step - loss: 1.8746 - accuracy: 0.3155 - val_loss: 1.7699 - val_accuracy: 0.3526
# Epoch 9/50
# 50000/50000 [==============================] - 18s 353us/step - loss: 1.8685 - accuracy: 0.3198 - val_loss: 1.8171 - val_accuracy: 0.3496
# Epoch 10/50
# 50000/50000 [==============================] - 18s 351us/step - loss: 1.8630 - accuracy: 0.3230 - val_loss: 1.7710 - val_accuracy: 0.3519
# Epoch 11/50
# 50000/50000 [==============================] - 17s 349us/step - loss: 1.8572 - accuracy: 0.3252 - val_loss: 1.7998 - val_accuracy: 0.3447
# Epoch 12/50
# 50000/50000 [==============================] - 17s 350us/step - loss: 1.8569 - accuracy: 0.3232 - val_loss: 1.8592 - val_accuracy: 0.3338
# Epoch 13/50
# 50000/50000 [==============================] - 17s 348us/step - loss: 1.8487 - accuracy: 0.3290 - val_loss: 1.7809 - val_accuracy: 0.3634
# Epoch 14/50
# 50000/50000 [==============================] - 17s 348us/step - loss: 1.8495 - accuracy: 0.3306 - val_loss: 1.7718 - val_accuracy: 0.3692
# Epoch 15/50
# 50000/50000 [==============================] - 17s 349us/step - loss: 1.8512 - accuracy: 0.3284 - val_loss: 1.7992 - val_accuracy: 0.3483
# Epoch 16/50
# 50000/50000 [==============================] - 18s 358us/step - loss: 1.8488 - accuracy: 0.3320 - val_loss: 1.8193 - val_accuracy: 0.3324
# Epoch 17/50
# 50000/50000 [==============================] - 18s 355us/step - loss: 1.8468 - accuracy: 0.3285 - val_loss: 1.8424 - val_accuracy: 0.3356
# Epoch 18/50
# 50000/50000 [==============================] - 18s 350us/step - loss: 1.8438 - accuracy: 0.3317 - val_loss: 1.7659 - val_accuracy: 0.3703
# Epoch 19/50
# 50000/50000 [==============================] - 18s 353us/step - loss: 1.8431 - accuracy: 0.3321 - val_loss: 1.7638 - val_accuracy: 0.3582
# Epoch 20/50
# 50000/50000 [==============================] - 17s 348us/step - loss: 1.8436 - accuracy: 0.3318 - val_loss: 1.7841 - val_accuracy: 0.3662
# Epoch 21/50
# 50000/50000 [==============================] - 17s 348us/step - loss: 1.8403 - accuracy: 0.3359 - val_loss: 1.7411 - val_accuracy: 0.3844
# Epoch 22/50
# 50000/50000 [==============================] - 17s 348us/step - loss: 1.8358 - accuracy: 0.3394 - val_loss: 1.7614 - val_accuracy: 0.3712
# Epoch 23/50
# 50000/50000 [==============================] - 17s 350us/step - loss: 1.8368 - accuracy: 0.3405 - val_loss: 1.7197 - val_accuracy: 0.3830
# Epoch 24/50
# 50000/50000 [==============================] - 17s 347us/step - loss: 1.8333 - accuracy: 0.3396 - val_loss: 1.7394 - val_accuracy: 0.3697
# Epoch 25/50
# 50000/50000 [==============================] - 18s 364us/step - loss: 1.8301 - accuracy: 0.3382 - val_loss: 1.7389 - val_accuracy: 0.3718
# Epoch 26/50
# 50000/50000 [==============================] - 17s 345us/step - loss: 1.8306 - accuracy: 0.3374 - val_loss: 1.7444 - val_accuracy: 0.3710
# Epoch 27/50
# 50000/50000 [==============================] - 17s 348us/step - loss: 1.8348 - accuracy: 0.3382 - val_loss: 1.7622 - val_accuracy: 0.3641
# Epoch 28/50
# 50000/50000 [==============================] - 17s 346us/step - loss: 1.8303 - accuracy: 0.3402 - val_loss: 1.7920 - val_accuracy: 0.3580
# Epoch 29/50
# 50000/50000 [==============================] - 17s 349us/step - loss: 1.8310 - accuracy: 0.3401 - val_loss: 1.8206 - val_accuracy: 0.3340
# Epoch 30/50
# 50000/50000 [==============================] - 17s 347us/step - loss: 1.8281 - accuracy: 0.3407 - val_loss: 1.7539 - val_accuracy: 0.3593
# Epoch 31/50
# 50000/50000 [==============================] - 17s 347us/step - loss: 1.8282 - accuracy: 0.3387 - val_loss: 1.8249 - val_accuracy: 0.3435
# Epoch 32/50
# 50000/50000 [==============================] - 17s 348us/step - loss: 1.8176 - accuracy: 0.3419 - val_loss: 1.7256 - val_accuracy: 0.3809
# Epoch 33/50
# 50000/50000 [==============================] - 17s 348us/step - loss: 1.8224 - accuracy: 0.3427 - val_loss: 1.7063 - val_accuracy: 0.3886
# Epoch 34/50
# 50000/50000 [==============================] - 18s 356us/step - loss: 1.8245 - accuracy: 0.3431 - val_loss: 1.7598 - val_accuracy: 0.3672
# Epoch 35/50
# 50000/50000 [==============================] - 17s 348us/step - loss: 1.8137 - accuracy: 0.3441 - val_loss: 1.7502 - val_accuracy: 0.3660
# Epoch 36/50
# 50000/50000 [==============================] - 17s 348us/step - loss: 1.8115 - accuracy: 0.3461 - val_loss: 1.7289 - val_accuracy: 0.3659
# Epoch 37/50
# 50000/50000 [==============================] - 17s 347us/step - loss: 1.8118 - accuracy: 0.3464 - val_loss: 1.7659 - val_accuracy: 0.3553
# Epoch 38/50
# 50000/50000 [==============================] - 17s 348us/step - loss: 1.8124 - accuracy: 0.3466 - val_loss: 1.7580 - val_accuracy: 0.3539
# Epoch 39/50
# 50000/50000 [==============================] - 18s 350us/step - loss: 1.8125 - accuracy: 0.3451 - val_loss: 1.7368 - val_accuracy: 0.3905
# Epoch 40/50
# 50000/50000 [==============================] - 17s 348us/step - loss: 1.8075 - accuracy: 0.3459 - val_loss: 1.7277 - val_accuracy: 0.3559
# Epoch 41/50
# 50000/50000 [==============================] - 17s 348us/step - loss: 1.8115 - accuracy: 0.3469 - val_loss: 1.7422 - val_accuracy: 0.3715
# Epoch 42/50
# 50000/50000 [==============================] - 17s 348us/step - loss: 1.8095 - accuracy: 0.3467 - val_loss: 1.7274 - val_accuracy: 0.3788
# Epoch 43/50
# 50000/50000 [==============================] - 18s 352us/step - loss: 1.8107 - accuracy: 0.3450 - val_loss: 1.7435 - val_accuracy: 0.3936
# Epoch 44/50
# 50000/50000 [==============================] - 18s 354us/step - loss: 1.8103 - accuracy: 0.3474 - val_loss: 1.7456 - val_accuracy: 0.3735
# Epoch 45/50
# 50000/50000 [==============================] - 17s 348us/step - loss: 1.8095 - accuracy: 0.3480 - val_loss: 1.7391 - val_accuracy: 0.3856
# Epoch 46/50
# 50000/50000 [==============================] - 18s 350us/step - loss: 1.8088 - accuracy: 0.3469 - val_loss: 1.7592 - val_accuracy: 0.3692
# Epoch 47/50
# 50000/50000 [==============================] - 18s 352us/step - loss: 1.8060 - accuracy: 0.3463 - val_loss: 1.8095 - val_accuracy: 0.3406
# Epoch 48/50
# 50000/50000 [==============================] - 17s 340us/step - loss: 1.8066 - accuracy: 0.3512 - val_loss: 1.8682 - val_accuracy: 0.3308
# Epoch 49/50
# 50000/50000 [==============================] - 17s 341us/step - loss: 1.8041 - accuracy: 0.3463 - val_loss: 1.7183 - val_accuracy: 0.3606
# Epoch 50/50
# 50000/50000 [==============================] - 17s 342us/step - loss: 1.8056 - accuracy: 0.3471 - val_loss: 1.7405 - val_accuracy: 0.3859
# Test loss: 1.7404887956619264
# Test accuracy: 0.38589999079704285

# %% [markdown]
# ## 增加神經網路層數(4層隱藏層), epoch=30，準確率從45%上升到51%

# %%
epochs=30

model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(3072,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))

model.summary()

model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_29 (Dense)             (None, 512)               1573376
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_30 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_31 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_26 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_32 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_27 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_33 (Dense)             (None, 10)                5130
# =================================================================
# Total params: 2,366,474
# Trainable params: 2,366,474
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/30
# 50000/50000 [==============================] - 29s 572us/step - loss: 2.0700 - accuracy: 0.2145 - val_loss: 2.2184 - val_accuracy: 0.2022
# Epoch 2/30
# 50000/50000 [==============================] - 27s 539us/step - loss: 1.9094 - accuracy: 0.3024 - val_loss: 1.9292 - val_accuracy: 0.2959
# Epoch 3/30
# 50000/50000 [==============================] - 26s 517us/step - loss: 1.8201 - accuracy: 0.3404 - val_loss: 1.8242 - val_accuracy: 0.3420
# Epoch 4/30
# 50000/50000 [==============================] - 26s 519us/step - loss: 1.7675 - accuracy: 0.3586 - val_loss: 1.6967 - val_accuracy: 0.3807
# Epoch 5/30
# 50000/50000 [==============================] - 26s 516us/step - loss: 1.7191 - accuracy: 0.3764 - val_loss: 1.6943 - val_accuracy: 0.3895
# Epoch 6/30
# 50000/50000 [==============================] - 25s 510us/step - loss: 1.6792 - accuracy: 0.3935 - val_loss: 1.6001 - val_accuracy: 0.4224
# Epoch 7/30
# 50000/50000 [==============================] - 26s 511us/step - loss: 1.6409 - accuracy: 0.4104 - val_loss: 1.6393 - val_accuracy: 0.4240
# Epoch 8/30
# 50000/50000 [==============================] - 26s 515us/step - loss: 1.6112 - accuracy: 0.4204 - val_loss: 1.6985 - val_accuracy: 0.4045
# Epoch 9/30
# 50000/50000 [==============================] - 26s 512us/step - loss: 1.5875 - accuracy: 0.4289 - val_loss: 1.6045 - val_accuracy: 0.4352
# Epoch 10/30
# 50000/50000 [==============================] - 26s 516us/step - loss: 1.5640 - accuracy: 0.4386 - val_loss: 1.5032 - val_accuracy: 0.4619
# Epoch 11/30
# 50000/50000 [==============================] - 26s 519us/step - loss: 1.5396 - accuracy: 0.4474 - val_loss: 1.5070 - val_accuracy: 0.4620
# Epoch 12/30
# 50000/50000 [==============================] - 26s 519us/step - loss: 1.5185 - accuracy: 0.4572 - val_loss: 1.5257 - val_accuracy: 0.4581
# Epoch 13/30
# 50000/50000 [==============================] - 26s 516us/step - loss: 1.5022 - accuracy: 0.4615 - val_loss: 1.4583 - val_accuracy: 0.4765
# Epoch 14/30
# 50000/50000 [==============================] - 26s 516us/step - loss: 1.4884 - accuracy: 0.4670 - val_loss: 1.4389 - val_accuracy: 0.4806
# Epoch 15/30
# 50000/50000 [==============================] - 26s 523us/step - loss: 1.4722 - accuracy: 0.4725 - val_loss: 1.4595 - val_accuracy: 0.4765
# Epoch 16/30
# 50000/50000 [==============================] - 26s 521us/step - loss: 1.4606 - accuracy: 0.4784 - val_loss: 1.4751 - val_accuracy: 0.4746
# Epoch 17/30
# 50000/50000 [==============================] - 26s 522us/step - loss: 1.4447 - accuracy: 0.4818 - val_loss: 1.4490 - val_accuracy: 0.4842
# Epoch 18/30
# 50000/50000 [==============================] - 26s 523us/step - loss: 1.4334 - accuracy: 0.4855 - val_loss: 1.4116 - val_accuracy: 0.5020
# Epoch 19/30
# 50000/50000 [==============================] - 26s 512us/step - loss: 1.4269 - accuracy: 0.4905 - val_loss: 1.4022 - val_accuracy: 0.5006
# Epoch 20/30
# 50000/50000 [==============================] - 25s 509us/step - loss: 1.4112 - accuracy: 0.4966 - val_loss: 1.4109 - val_accuracy: 0.4954
# Epoch 21/30
# 50000/50000 [==============================] - 26s 513us/step - loss: 1.4019 - accuracy: 0.4977 - val_loss: 1.4384 - val_accuracy: 0.4935
# Epoch 22/30
# 50000/50000 [==============================] - 26s 513us/step - loss: 1.3933 - accuracy: 0.5026 - val_loss: 1.3682 - val_accuracy: 0.5093
# Epoch 23/30
# 50000/50000 [==============================] - 26s 515us/step - loss: 1.3872 - accuracy: 0.5045 - val_loss: 1.3730 - val_accuracy: 0.5124
# Epoch 24/30
# 50000/50000 [==============================] - 26s 516us/step - loss: 1.3733 - accuracy: 0.5093 - val_loss: 1.3867 - val_accuracy: 0.5058
# Epoch 25/30
# 50000/50000 [==============================] - 26s 520us/step - loss: 1.3661 - accuracy: 0.5170 - val_loss: 1.4725 - val_accuracy: 0.4680
# Epoch 26/30
# 50000/50000 [==============================] - 26s 521us/step - loss: 1.3576 - accuracy: 0.5143 - val_loss: 1.3963 - val_accuracy: 0.4985
# Epoch 27/30
# 50000/50000 [==============================] - 26s 515us/step - loss: 1.3551 - accuracy: 0.5176 - val_loss: 1.4284 - val_accuracy: 0.4944
# Epoch 28/30
# 50000/50000 [==============================] - 26s 516us/step - loss: 1.3476 - accuracy: 0.5201 - val_loss: 1.3709 - val_accuracy: 0.5156
# Epoch 29/30
# 50000/50000 [==============================] - 26s 520us/step - loss: 1.3406 - accuracy: 0.5215 - val_loss: 1.3670 - val_accuracy: 0.5151
# Epoch 30/30
# 50000/50000 [==============================] - 26s 519us/step - loss: 1.3335 - accuracy: 0.5241 - val_loss: 1.3663 - val_accuracy: 0.5131
# Test loss: 1.3662597036361694
# Test accuracy: 0.5131000280380249

# %% [markdown]
#     2. CNN 與 DNN 哪個模型的參數數量比較多? 造成參數的數量不同的原因在哪?

# %% [markdown]
#     - 參數數量：DNN：1,841,162 / CNN：1,250,858
#     - CNN的捲積層和池化層會讓參數少很多
